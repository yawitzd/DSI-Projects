# %%
import pandas as pd

# %%
def fizzbuzz(n):
    if n%15 == 0:
        return 'FizzBuzz'
    elif n%3 == 0:
        return 'Fizz'
    elif n%5 == 0:
        return 'Buzz'
    else:
        return n

# %%
nums = [range(0,101)]

df = pd.DataFrame(nums)

df = df.T

# %%
df['FizzBuzz'] = df.applymap(fizzbuzz)

# %%
df
# Out:
#        0  FizzBuzz
# 0      0  FizzBuzz
# 1      1         1
# 2      2         2
# 3      3      Fizz
# 4      4         4
# 5      5      Buzz
# 6      6      Fizz
# 7      7         7
# 8      8         8
# 9      9      Fizz
# 10    10      Buzz
# 11    11        11
# 12    12      Fizz
# 13    13        13
# 14    14        14
# 15    15  FizzBuzz
# 16    16        16
# 17    17        17
# 18    18      Fizz
# 19    19        19
# 20    20      Buzz
# 21    21      Fizz
# 22    22        22
# 23    23        23
# 24    24      Fizz
# 25    25      Buzz
# 26    26        26
# 27    27      Fizz
# 28    28        28
# 29    29        29
# ..   ...       ...
# 71    71        71
# 72    72      Fizz
# 73    73        73
# 74    74        74
# 75    75  FizzBuzz
# 76    76        76
# 77    77        77
# 78    78      Fizz
# 79    79        79
# 80    80      Buzz
# 81    81      Fizz
# 82    82        82
# 83    83        83
# 84    84      Fizz
# 85    85      Buzz
# ...

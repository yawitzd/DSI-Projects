# %%
import pandas as pd

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('/Users/TuckerCS/Dropbox/DSI-Projects/week02/salary.csv')

# %%
df.head()
# Out:
#        sx    rk  yr         dg  yd     sl  js
# 0    male  full  25  doctorate  35  36350  10
# 1    male  full  13  doctorate  22  35350   9
# 2    male  full  10  doctorate  23  28200  13
# 3  female  full   7  doctorate  27  26775  20
# 4    male  full  19    masters  30  33696  11

# %%
df.tail()
# Out:
#         sx         rk  yr         dg  yd     sl  js
# 47  female  assistant   2  doctorate   2  15350   0
# 48    male  assistant   1  doctorate   1  16244   0
# 49  female  assistant   1  doctorate   1  16686   0
# 50  female  assistant   1  doctorate   1  15000   0
# 51  female  assistant   0  doctorate   2  20300   2

# %%
df.head(20)
# Out:
#         sx         rk  yr         dg  yd     sl  js
# 0     male       full  25  doctorate  35  36350  10
# 1     male       full  13  doctorate  22  35350   9
# 2     male       full  10  doctorate  23  28200  13
# 3   female       full   7  doctorate  27  26775  20
# 4     male       full  19    masters  30  33696  11
# 5     male       full  16  doctorate  21  28516   5
# 6   female       full   0    masters  32  24900  32
# 7     male       full  16  doctorate  18  31909   2
# 8     male       full  13    masters  30  31850  17
# 9     male       full  13    masters  31  32850  18
# 10    male       full  12  doctorate  22  27025  10
# 11    male  associate  15  doctorate  19  24750   4
# 12    male       full   9  doctorate  17  28200   8
# 13    male  associate   9    masters  27  23712  18
# 14    male       full   9  doctorate  24  25748  15
# 15    male       full   7  doctorate  15  29342   8
# 16    male       full  13  doctorate  20  31114   7
# ...

# %%
df.describe()
# Out:
#               yr         yd            sl         js
# count  52.000000  52.000000     52.000000  52.000000
# mean    7.480769  16.115385  23797.653846   8.634615
# std     5.507536  10.222340   5917.289154   7.931147
# min     0.000000   1.000000  15000.000000  -1.000000
# 25%     3.000000   6.750000  18246.750000   2.750000
# 50%     7.000000  15.500000  23719.000000   7.000000
# 75%    11.000000  23.250000  27258.500000  13.250000
# max    25.000000  35.000000  38045.000000  32.000000

# %%
df.describe(percentiles=(.10,.20,.50,.80))
# Out:
#               yr         yd            sl         js
# count  52.000000  52.000000     52.000000  52.000000
# mean    7.480769  16.115385  23797.653846   8.634615
# std     5.507536  10.222340   5917.289154   7.931147
# min     0.000000   1.000000  15000.000000  -1.000000
# 10%     1.000000   2.100000  16518.600000   0.000000
# 20%     2.200000   4.200000  17680.000000   1.200000
# 50%     7.000000  15.500000  23719.000000   7.000000
# 80%    11.800000  26.400000  28200.000000  15.000000
# max    25.000000  35.000000  38045.000000  32.000000

# %%
df.count()
# Out:
# sx    52
# rk    52
# yr    52
# dg    52
# yd    52
# sl    52
# js    52
# dtype: int64

# %%
df.mean()
# Out:
# yr        7.480769
# yd       16.115385
# sl    23797.653846
# js        8.634615
# dtype: float64

# %%
df.median()
# Out:
# yr        7.0
# yd       15.5
# sl    23719.0
# js        7.0
# dtype: float64

# %%
df.max()
# Out:
# sx       male
# rk       full
# yr         25
# dg    masters
# yd         35
# sl      38045
# js         32
# dtype: object

# %%
df.min()
# Out:
# sx       female
# rk    assistant
# yr            0
# dg    doctorate
# yd            1
# sl        15000
# js           -1
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
# sx    52 non-null object
# rk    52 non-null object
# yr    52 non-null int64
# dg    52 non-null object
# yd    52 non-null int64
# sl    52 non-null int64
# js    52 non-null int64
# dtypes: int64(4), object(3)
# memory usage: 2.9+ KB

# %%
df[0:3]
# Out:
#      sx    rk  yr         dg  yd     sl  js
# 0  male  full  25  doctorate  35  36350  10
# 1  male  full  13  doctorate  22  35350   9
# 2  male  full  10  doctorate  23  28200  13

# %%
df['sx']
# Out:
# 0       male
# 1       male
# 2       male
# 3     female
# 4       male
# 5       male
# 6     female
# 7       male
# 8       male
# 9       male
# 10      male
# 11      male
# 12      male
# 13      male
# 14      male
# 15      male
# 16      male
# 17      male
# 18      male
# 19      male
# 20      male
# 21      male
# 22      male
# 23    female
# 24      male
# 25      male
# 26      male
# 27    female
# 28      male
# 29      male
# 30    female
# 31      male
# 32      male
# 33    female
# 34    female
# 35      male
# 36    female
# 37      male
# 38      male
# 39      male
# 40      male
# 41      male
# 42      male
# 43    female
# 44      male
# 45      male
# 46    female
# 47    female
# 48      male
# 49    female
# 50    female
# 51    female
# Name: sx, dtype: object

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df['sx'])
# Out:
# pandas.core.series.Series

# %%
cols_i_want = ['sx', 'yr', 'sl']

df[cols_i_want][0:5]
# Out:
#        sx  yr     sl
# 0    male  25  36350
# 1    male  13  35350
# 2    male  10  28200
# 3  female   7  26775
# 4    male  19  33696

# %%
df.iloc[0:10,2:4]
# Out:
#    yr         dg
# 0  25  doctorate
# 1  13  doctorate
# 2  10  doctorate
# 3   7  doctorate
# 4  19    masters
# 5  16  doctorate
# 6   0    masters
# 7  16  doctorate
# 8  13    masters
# 9  13    masters

# %%
df.iloc[1,3]
# Out:
# 'doctorate'

# %%
df['yr'].hist()

# %%
df['js'].hist(figsize=(8,5), color='k')

# %%
fig = df['yr'].hist(figsize=(8,5), color='k')

plt.style.use('fivethirtyeight')

ax = plt.gca()

ax.set_ylabel('Frequency', fontsize=14)
ax.set_xlabel('Years', fontsize=14)

fig.set_title('A Chart of Stuff', y=1.01)

# %%
## reading in as encoding='latin-1' got rid of some weird characters in the file ##

sw = pd.read_csv('/Users/TuckerCS/Dropbox/DSI-Projects/week02/star_wars.csv', encoding='latin-1')

# %%
sw.head()
# Out:
#    RespondentID Have you seen any of the 6 films in the Star Wars franchise?  \
# 0           NaN                                           Response
# 1  3.292880e+09                                                Yes
# 2  3.292880e+09                                                 No
# 3  3.292765e+09                                                Yes
# 4  3.292763e+09                                                Yes
#
#   Do you consider yourself to be a fan of the Star Wars film franchise?  \
# 0                                           Response
# 1                                                Yes
# 2                                                NaN
# 3                                                 No
# 4                                                Yes
#
#   Which of the following Star Wars films have you seen? Please select all that apply.  \
# 0           Star Wars: Episode I  The Phantom Menace
# 1           Star Wars: Episode I  The Phantom Menace
# ...

# %%
sw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1187 entries, 0 to 1186
# Data columns (total 38 columns):
# RespondentID                                                                                                                                     1186 non-null float64
# Have you seen any of the 6 films in the Star Wars franchise?                                                                                     1187 non-null object
# Do you consider yourself to be a fan of the Star Wars film franchise?                                                                            837 non-null object
# Which of the following Star Wars films have you seen? Please select all that apply.                                                              674 non-null object
# Unnamed: 4                                                                                                                                       572 non-null object
# ...

# %%
sw.iloc[0:,0:2]
# Out:
#       RespondentID  \
# 0              NaN
# 1     3.292880e+09
# 2     3.292880e+09
# 3     3.292765e+09
# 4     3.292763e+09
# 5     3.292731e+09
# 6     3.292719e+09
# 7     3.292685e+09
# 8     3.292664e+09
# 9     3.292654e+09
# 10    3.292640e+09
# 11    3.292638e+09
# 12    3.292635e+09
# 13    3.292609e+09
# 14    3.292597e+09
# 15    3.292587e+09
# 16    3.292583e+09
# 17    3.292581e+09
# 18    3.292573e+09
# 19    3.292565e+09
# 20    3.292562e+09
# 21    3.292522e+09
# 22    3.292521e+09
# 23    3.292512e+09
# 24    3.292483e+09
# 25    3.292465e+09
# 26    3.292448e+09
# 27    3.292420e+09
# 28    3.292384e+09
# 29    3.292380e+09
# ...            ...
# 1157  3.288426e+09
# 1158  3.288423e+09
# 1159  3.288423e+09
# 1160  3.288422e+09
# 1161  3.288421e+09
# 1162  3.288418e+09
# 1163  3.288418e+09
# 1164  3.288417e+09
# 1165  3.288415e+09
# 1166  3.288414e+09
# 1167  3.288413e+09
# 1168  3.288410e+09
# 1169  3.288410e+09
# 1170  3.288409e+09
# 1171  3.288403e+09
# ...

# %%
type(sw['RespondentID'])
# Out:
# pandas.core.series.Series

# %%
han_columns = ['RespondentID','Which character shot first?', 'Gender', 'Age']

sw[han_columns][1:]
# Out:
#       RespondentID       Which character shot first?  Gender    Age
# 1     3.292880e+09  I don't understand this question    Male  18-29
# 2     3.292880e+09                               NaN    Male  18-29
# 3     3.292765e+09  I don't understand this question    Male  18-29
# 4     3.292763e+09  I don't understand this question    Male  18-29
# 5     3.292731e+09                            Greedo    Male  18-29
# 6     3.292719e+09                               Han    Male  18-29
# 7     3.292685e+09                               Han    Male  18-29
# 8     3.292664e+09                               Han    Male  18-29
# 9     3.292654e+09                               Han    Male  18-29
# 10    3.292640e+09  I don't understand this question    Male  18-29
# 11    3.292638e+09                               NaN     NaN    NaN
# 12    3.292635e+09                               NaN     NaN    NaN
# 13    3.292609e+09                            Greedo    Male  18-29
# ...

# %%
sw.loc[:, "RespondentID"] = sw["RespondentID"].astype("str")

# %%
sw.loc[0:5,'RespondentID']
# Out:
# 0             nan
# 1    3292879998.0
# 2    3292879538.0
# 3    3292765271.0
# 4    3292763116.0
# 5    3292731220.0
# Name: RespondentID, dtype: object

# %%
sw.index
# Out:
# RangeIndex(start=0, stop=1187, step=1)

# %%
cols = [x for x in sw.columns if 'Do' in x]

# %%
cols
# Out:
# [u'Do you consider yourself to be a fan of the Star Wars film franchise?',
#  u'Do you consider yourself to be a fan of the Expanded Universe?\xef\xbf\xbd\xef\xbf\xbd',
#  u'Do you consider yourself to be a fan of the Star Trek franchise?']

# %%
sw.loc[:, cols]
# Out:
#      Do you consider yourself to be a fan of the Star Wars film franchise?  \
# 0                                              Response
# 1                                                   Yes
# 2                                                   NaN
# 3                                                    No
# 4                                                   Yes
# 5                                                   Yes
# 6                                                   Yes
# 7                                                   Yes
# 8                                                   Yes
# 9                                                   Yes
# 10                                                   No
# 11                                                  NaN
# 12                                                  NaN
# 13                                                   No
# 14                                                  Yes
# ...

# %%
## iloc uses index wheras loc uses name (i.e., column name) ##

sw.iloc[:,1]
# Out:
# 0       Response
# 1            Yes
# 2             No
# 3            Yes
# 4            Yes
# 5            Yes
# 6            Yes
# 7            Yes
# 8            Yes
# 9            Yes
# 10           Yes
# 11           Yes
# 12            No
# 13           Yes
# 14           Yes
# 15           Yes
# 16           Yes
# 17           Yes
# 18           Yes
# 19           Yes
# 20           Yes
# 21           Yes
# 22           Yes
# 23           Yes
# 24           Yes
# 25           Yes
# 26            No
# 27           Yes
# 28           Yes
# 29           Yes
#           ...
# 1157         Yes
# 1158          No
# 1159         Yes
# 1160          No
# 1161         Yes
# 1162         Yes
# 1163         Yes
# 1164         Yes
# 1165         Yes
# 1166         Yes
# 1167         Yes
# 1168         Yes
# 1169          No
# 1170         Yes
# 1171          No
# 1172         Yes
# 1173         Yes
# 1174         Yes
# 1175         Yes
# 1176         Yes
# 1177         Yes
# ...

# %%
sw['NewColumn'] = 1

# %%
sw.head(3)
# Out:
#    RespondentID Have you seen any of the 6 films in the Star Wars franchise?  \
# 0           nan                                           Response
# 1  3292879998.0                                                Yes
# 2  3292879538.0                                                 No
#
#   Do you consider yourself to be a fan of the Star Wars film franchise?  \
# 0                                           Response
# 1                                                Yes
# 2                                                NaN
#
#   Which of the following Star Wars films have you seen? Please select all that apply.  \
# 0           Star Wars: Episode I  The Phantom Menace
# 1           Star Wars: Episode I  The Phantom Menace
# 2                                                NaN
#
#                                     Unnamed: 4  \
# 0  Star Wars: Episode II  Attack of the Clones
# 1  Star Wars: Episode II  Attack of the Clones
# 2                                          NaN
#
# ...
